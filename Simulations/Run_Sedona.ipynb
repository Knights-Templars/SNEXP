# %%
import os
import re
import glob
import shutil

# %%
working_directory = '/Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/'
os.chdir(working_directory)

# %%
list_param_files = glob.glob(working_directory + '*.lua')
sedona_executable = 'sedona6.ex'

# %%
#list_param_files
# Out:
# ['/Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/param_model_1.8_1.7e+51.lua',
#  '/Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/param_model_1.4_1.7e+51.lua',
#  '/Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/param_model_1.2_1.7e+51.lua',
#  '/Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/param_model_2.0_1.7e+51.lua',
#  '/Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/param_model_1.0_1.7e+51.lua',
#  '/Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/param_model_1.6_1.7e+51.lua']

# %%
list_model_files = glob.glob(working_directory + '*.mod')

# %%
#list_model_files
# Out:
# ['/Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/sed_model_1.2_1.7e+51.mod',
#  '/Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/sed_model_1.4_1.7e+51.mod',
#  '/Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/sed_model_1.8_1.7e+51.mod',
#  '/Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/sed_model_1.6_1.7e+51.mod',
#  '/Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/sed_model_1.0_1.7e+51.mod',
#  '/Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/sed_model_2.0_1.7e+51.mod']

# %%
for i in range(len(list_model_files)):
    
    file = list_model_files[i].split('/')[-1]
    name = file[4:21]
    
    for j in range(len(list_param_files)):
        
        param_file = list_param_files[j].split('/')[-1]
        if name in param_file:
            if os.path.exists(name):
                shutil.rmtree(name)
            os.mkdir(name)
            shutil.copy(file, name)
            shutil.copy(param_file, name)
            shutil.copy(sedona_executable, name)

# %%
for root, subdirectories, files in os.walk(working_directory):
    for i in subdirectories:
        os.chdir(root + i)
        for j in glob.glob('param_*'):
            print ("Running Sedona in %s"%os.getcwd())
            command = "mpirun -n 8 ./sedona6.ex %s"%j
            os.system(command)
            #print (os.listdir())
# Out:
# Running Sedona in /Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/model_1.6_1.7e+51
# ##################################
# ############  sedona  ############
# ##################################
# #
# # MPI tasks = 8
# # threads per task = 1
# #
# #
# #
# #
# #
# #
# # git version
# # compiled on
# #
# #
# #
# ##################################
# #
# # model file is ASCII format (.mod)
# # model file = sed_model_1.6_1.7e+51.mod
# # Model is a 1D_sphere
# #
# ####### 1D STANDARD MODEL ##########
# # n_x = 100
# # elems (n=10) 6.12 8.16 10.2 12.24 14.28 16.32 20.4 26.54 28.56 28.58
# #
# # mass = 3.1833e+33 (1.6005e+00 Msun)
# # 6.12	1.55028e+33 (0.779459 Msun)
# # 8.16	1.63305e+33 (0.821073 Msun)
# # 10.2	0 (0 Msun)
# # 12.24	0 (0 Msun)
# # 14.28	0 (0 Msun)
# # 16.32	0 (0 Msun)
# # 20.4	0 (0 Msun)
# # 26.54	0 (0 Msun)
# # 28.56	0 (0 Msun)
# # 28.58	0 (0 Msun)
# # kinetic energy   = 1.7530e+51
# # radiation energy = 6.5232e+44
# ##############################
# #
# # t_start = 86400, t_now = 86400#
# # Adiabatically expanding rho and T from input model
# # Assumes rad pressure dominated; includes radioactive heating
# # frequency grid: n = 17664
# # From fuzzfile "/Users/anirbandutta/Downloads/pubsed-main/data/kurucz_cd23_fuzz.hdf5" 201537 lines used
# #-------------------------------------------------
# # atomic data from:
# #--------------------------------------------------
# #  Z    n_ions  n_levels  n_lines  n_fuzz_lines
# #-------------------------------------------------
# #  6.12     7      392         0      7517
# #  8.16     7      299         0      5240
# # 10.2     7      340         0      8310
# # 12.24     7      319         0      3389
# # 14.28     7      429         0      7708
# # 16.32     7      316         0      1779
# # 20.4     7      448         0     13399
# # 26.54     7     1875         0     93391
# # 28.56     7      968         0     60804
# # 28.58     7      968         0     60804
# #-------------------------------------------------
# # opacity settings
# #-------------------------------------------------
# # use_e_scattering    = 1
# # use_free_free       = 1
# # use_bound_free      = 1
# # use_bound_bound     = 1
# # use_line_exp        = 1
# # use_fuzz_exp        = 1
# # use_nlte            = 0
# # use_collisions_nlte = 1
# #---------------------------------------
# # init with 10000 total particles (1250 per MPI proc)
#
# # There are 1 instances of the GasState class. For each:
# # Memory usage for transport data (for each gas state class)
# #---------------------------------------------------------|
# #  data   | # vars |     # pts | each(B)|       total (B) |
# #---------------------------------------------------------|
# # zone    |      7 |       100 |      8 |           5,600 |
# # freq    |      4 | 1,766,400 |      8 |      56,524,800 |
# #---------------------------------------------------------|
# #-----------------------------------------------------|
# #  data   |       number |  each (B) |      total (B) |
# #-----------------------------------------------------|
# # lines   |            0 |        56 |              0 |
# # levels  |        6,354 |       136 |        864,144 |
# # total   |              |           |        864,144 |
# #-----------------------------------------------------|
#
# # Setup Done: took 0.212287 seconds
# # writing initial plot file
# #-------------------------------------------
# # TSTEP #1 ; t = 8.64e+04 sec (1.00e+00 days); dt = 8.64e+03
# # particles on grid = 1250
# # Calculated opacities   (5.35e+01 secs)
# # Communicated opacities (1.48e-01 secs)
# Running Sedona in /Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/model_1.4_1.7e+51
# ##################################
# ############  sedona  ############
# ##################################
# #
# # MPI tasks = 8
# # threads per task = 1
# #
# #
# #
# #
# #
# # git version
# # compiled on
# #
# #
# #
# ##################################
# #
# # model file is ASCII format (.mod)
# #
# # model file = sed_model_1.4_1.7e+51.mod
# # Model is a 1D_sphere
# #
# ####### 1D STANDARD MODEL ##########
# # n_x = 100
# # elems (n=10) 6.12 8.16 10.2 12.24 14.28 16.32 20.4 26.54 28.56 28.58
# #
# # mass = 2.7847e+33 (1.4001e+00 Msun)
# # 6.12	1.35614e+33 (0.681845 Msun)
# # 8.16	1.42854e+33 (0.718247 Msun)
# # 10.2	0 (0 Msun)
# # 12.24	0 (0 Msun)
# # 14.28	0 (0 Msun)
# # 16.32	0 (0 Msun)
# # 20.4	0 (0 Msun)
# # 26.54	0 (0 Msun)
# # 28.56	0 (0 Msun)
# # 28.58	0 (0 Msun)
# # kinetic energy   = 1.7451e+51
# # radiation energy = 6.5232e+44
# ##############################
# #
# # t_start = 86400, t_now = 86400#
# # Adiabatically expanding rho and T from input model
# # Assumes rad pressure dominated; includes radioactive heating
# # frequency grid: n = 17664
# # From fuzzfile "/Users/anirbandutta/Downloads/pubsed-main/data/kurucz_cd23_fuzz.hdf5" 201537 lines used
# #-------------------------------------------------
# # atomic data from:
# #--------------------------------------------------
# #  Z    n_ions  n_levels  n_lines  n_fuzz_lines
# #-------------------------------------------------
# #  6.12     7      392         0      7517
# #  8.16     7      299         0      5240
# # 10.2     7      340         0      8310
# # 12.24     7      319         0      3389
# # 14.28     7      429         0      7708
# # 16.32     7      316         0      1779
# # 20.4     7      448         0     13399
# # 26.54     7     1875         0     93391
# # 28.56     7      968         0     60804
# # 28.58     7      968         0     60804
# #-------------------------------------------------
# # opacity settings
# #-------------------------------------------------
# # use_e_scattering    = 1
# # use_free_free       = 1
# # use_bound_free      = 1
# # use_bound_bound     = 1
# # use_line_exp        = 1
# # use_fuzz_exp        = 1
# # use_nlte            = 0
# # use_collisions_nlte = 1
# #---------------------------------------
# # init with 10000 total particles (1250 per MPI proc)
#
# # There are 1 instances of the GasState class. For each:
# # Memory usage for transport data (for each gas state class)
# #---------------------------------------------------------|
# #  data   | # vars |     # pts | each(B)|       total (B) |
# #---------------------------------------------------------|
# # zone    |      7 |       100 |      8 |           5,600 |
# # freq    |      4 | 1,766,400 |      8 |      56,524,800 |
# #---------------------------------------------------------|
# #-----------------------------------------------------|
# #  data   |       number |  each (B) |      total (B) |
# #-----------------------------------------------------|
# # lines   |            0 |        56 |              0 |
# # levels  |        6,354 |       136 |        864,144 |
# # total   |              |           |        864,144 |
# #-----------------------------------------------------|
#
# # Setup Done: took 0.074737 seconds
# # writing initial plot file
# #-------------------------------------------
# # TSTEP #1 ; t = 8.64e+04 sec (1.00e+00 days); dt = 8.64e+03
# # particles on grid = 1250
# Running Sedona in /Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/model_2.0_1.7e+51
# ##################################
# ############  sedona  ############
# ##################################
# #
# # MPI tasks = 8
# # threads per task = 1
# #
# #
# #
# #
# #
# # git version
# # compiled on
# #
# ##################################
# #
# # model file is ASCII format (.mod)
# #
# #
# #
# # model file = sed_model_2.0_1.7e+51.mod
# # Model is a 1D_sphere
# #
# ####### 1D STANDARD MODEL ##########
# # n_x = 100
# # elems (n=10) 6.12 8.16 10.2 12.24 14.28 16.32 20.4 26.54 28.56 28.58
# #
# # mass = 3.9804e+33 (2.0013e+00 Msun)
# # 6.12	1.93844e+33 (0.974621 Msun)
# # 8.16	2.04193e+33 (1.02665 Msun)
# # 10.2	0 (0 Msun)
# # 12.24	0 (0 Msun)
# # 14.28	0 (0 Msun)
# # 16.32	0 (0 Msun)
# # 20.4	0 (0 Msun)
# # 26.54	0 (0 Msun)
# # 28.56	0 (0 Msun)
# # 28.58	0 (0 Msun)
# # kinetic energy   = 1.7633e+51
# # radiation energy = 6.5232e+44
# ##############################
# #
# # t_start = 86400, t_now = 86400#
# # Adiabatically expanding rho and T from input model
# # Assumes rad pressure dominated; includes radioactive heating
# # frequency grid: n = 17664
# # From fuzzfile "/Users/anirbandutta/Downloads/pubsed-main/data/kurucz_cd23_fuzz.hdf5" 201537 lines used
# #-------------------------------------------------
# # atomic data from:
# #--------------------------------------------------
# #  Z    n_ions  n_levels  n_lines  n_fuzz_lines
# #-------------------------------------------------
# #  6.12     7      392         0      7517
# #  8.16     7      299         0      5240
# # 10.2     7      340         0      8310
# # 12.24     7      319         0      3389
# # 14.28     7      429         0      7708
# # 16.32     7      316         0      1779
# # 20.4     7      448         0     13399
# # 26.54     7     1875         0     93391
# # 28.56     7      968         0     60804
# # 28.58     7      968         0     60804
# #-------------------------------------------------
# # opacity settings
# #-------------------------------------------------
# # use_e_scattering    = 1
# # use_free_free       = 1
# # use_bound_free      = 1
# # use_bound_bound     = 1
# # use_line_exp        = 1
# # use_fuzz_exp        = 1
# # use_nlte            = 0
# # use_collisions_nlte = 1
# #---------------------------------------
# # init with 10000 total particles (1250 per MPI proc)
#
# # There are 1 instances of the GasState class. For each:
# # Memory usage for transport data (for each gas state class)
# #---------------------------------------------------------|
# #  data   | # vars |     # pts | each(B)|       total (B) |
# #---------------------------------------------------------|
# # zone    |      7 |       100 |      8 |           5,600 |
# # freq    |      4 | 1,766,400 |      8 |      56,524,800 |
# #---------------------------------------------------------|
# #-----------------------------------------------------|
# #  data   |       number |  each (B) |      total (B) |
# #-----------------------------------------------------|
# # lines   |            0 |        56 |              0 |
# # levels  |        6,354 |       136 |        864,144 |
# # total   |              |           |        864,144 |
# #-----------------------------------------------------|
#
# # Setup Done: took 0.173148 seconds
# # writing initial plot file
# #-------------------------------------------
# # TSTEP #1 ; t = 8.64e+04 sec (1.00e+00 days); dt = 8.64e+03
# # particles on grid = 1250
# Running Sedona in /Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/model_1.0_1.7e+51
# Running Sedona in /Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/model_1.8_1.7e+51
# Running Sedona in /Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/Save
# ##################################
# ############  sedona  ############
# ##################################
# #
# # MPI tasks = 8
# # threads per task = 1
# #
# # git version
# # compiled on
# #
# ##################################
# #
# #
# #
# #
# #
# #
# #
# #
# # Don't recognize model file extension, assuming ascii
# Err: can't read model file: model_1.8_1.7e+51
# --------------------------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code. Per user-direction, the job has been aborted.
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# mpirun detected that one or more processes exited with non-zero status, thus causing
# the job to be terminated. The first process to do so was:
#
#   Process name: [[31151,1],4]
#   Exit code:    4
# --------------------------------------------------------------------------
# Running Sedona in /Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/Save
# ##################################
# ############  sedona  ############
# ##################################
# #
# # MPI tasks = 8
# # threads per task = 1
# #
# # git version
# # compiled on
# #
# ##################################
# #
# #
# #
# #
# #
# #
# #
# #
# # Don't recognize model file extension, assuming ascii
# Err: can't read model file: model_1.4_1.7e+51
# --------------------------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code. Per user-direction, the job has been aborted.
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# mpirun detected that one or more processes exited with non-zero status, thus causing
# the job to be terminated. The first process to do so was:
#
#   Process name: [[31140,1],5]
#   Exit code:    4
# --------------------------------------------------------------------------
# Running Sedona in /Users/anirbandutta/Documents/SNEXP/Violent_Merger_2012_Model_Ejecta/Save
# ##################################
# ############  sedona  ############
# ##################################
# #
# # MPI tasks = 8
# # threads per task = 1
# #
# #
# #
# #
# #
# #
# #
# # git version
# # compiled on
# #
# ##################################
# #
# #
# # Don't recognize model file extension, assuming ascii
# Err: can't read model file: model_1.2_1.7e+51
# --------------------------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code. Per user-direction, the job has been aborted.
# --------------------------------------------------------------------------
